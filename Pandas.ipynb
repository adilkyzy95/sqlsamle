# %% [markdown]
# <a href="https://colab.research.google.com/github/adilkyzy95/sqlsamle/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.kaggle.com/datasets/arashnic/hr-analytics-job-change-of-data-scientists

# %% [markdown]
# https://drive.google.com/file/d/1FNuH__wUB6Up9NEiIj_FfjyF54XFeY8b/view?usp=sharing

# %%
! gdown --id 1FNuH__wUB6Up9NEiIj_FfjyF54XFeY8b
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1FNuH__wUB6Up9NEiIj_FfjyF54XFeY8b
# To: /content/HR.zip
# 100% 302k/302k [00:00<00:00, 3.89MB/s]

# %%
! unzip /content/HR.zip
# Out:
# Archive:  /content/HR.zip
#   inflating: aug_test.csv
#   inflating: aug_train.csv
#   inflating: sample_submission.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/aug_train.csv')

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target
# 0                  36     1.0
# 1                  47     0.0
# 2                  83     0.0
# 3                  52     1.0
# 4                   8     0.0
# ...               ...     ...
# 19153              42     1.0
# 19154              52     1.0
# 19155              44     0.0
# 19156              97     0.0
# 19157             127     0.0
#
# [19158 rows x 14 columns]

# %%
df.head(10)
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
# 5        21651  city_176                   0.764    NaN
# 6        28806  city_160                   0.920   Male
# 7          402   city_46                   0.762   Male
# 8        27107  city_103                   0.920   Male
# 9          699  city_103                   0.920    NaN
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
# 5  Has relevent experience    Part time course        Graduate
# 6  Has relevent experience       no_enrollment     High School
# 7  Has relevent experience       no_enrollment        Graduate
# 8  Has relevent experience       no_enrollment        Graduate
# 9  Has relevent experience       no_enrollment        Graduate
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# 2             STEM          5          NaN             NaN        never
# 3  Business Degree         <1          NaN         Pvt Ltd        never
# 4             STEM        >20        50-99  Funded Startup            4
# 5             STEM         11          NaN             NaN            1
# 6              NaN          5        50-99  Funded Startup            1
# 7             STEM         13          <10         Pvt Ltd           >4
# 8             STEM          7        50-99         Pvt Ltd            1
# 9             STEM         17       10000+         Pvt Ltd           >4
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0
# 2              83     0.0
# 3              52     1.0
# 4               8     0.0
# 5              24     1.0
# 6              24     0.0
# 7              18     1.0
# 8              46     1.0
# 9             123     0.0

# %%
df.tail(5)
# Out:
#        enrollee_id      city  city_development_index gender  \
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size company_type last_new_job  \
# 19153       Humanities         14          NaN          NaN            1
# 19154             STEM         14          NaN          NaN            4
# 19155             STEM        >20        50-99      Pvt Ltd            4
# 19156              NaN         <1      500-999      Pvt Ltd            2
# 19157              NaN          2          NaN          NaN            1
#
#        training_hours  target
# 19153              42     1.0
# 19154              52     1.0
# 19155              44     0.0
# 19156              97     0.0
# 19157             127     0.0

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target
# 0                  36     1.0
# 1                  47     0.0
# 2                  83     0.0
# 3                  52     1.0
# 4                   8     0.0
# ...               ...     ...
# 19153              42     1.0
# 19154              52     1.0
# 19155              44     0.0
# 19156              97     0.0
# 19157             127     0.0
#
# [19158 rows x 14 columns]

# %%
df['city']
# Out:
# 0        city_103
# 1         city_40
# 2         city_21
# 3        city_115
# 4        city_162
#            ...
# 19153    city_173
# 19154    city_103
# 19155    city_103
# 19156     city_65
# 19157     city_67
# Name: city, Length: 19158, dtype: object

# %%
df[['city', 'city_development_index']]
# Out:
#            city  city_development_index
# 0      city_103                   0.920
# 1       city_40                   0.776
# 2       city_21                   0.624
# 3      city_115                   0.789
# 4      city_162                   0.767
# ...         ...                     ...
# 19153  city_173                   0.878
# 19154  city_103                   0.920
# 19155  city_103                   0.920
# 19156   city_65                   0.802
# 19157   city_67                   0.855
#
# [19158 rows x 2 columns]

# %%
print(df.head())
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# 2             STEM          5          NaN             NaN        never
# 3  Business Degree         <1          NaN         Pvt Ltd        never
# 4             STEM        >20        50-99  Funded Startup            4
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0
# 2              83     0.0
# 3              52     1.0
# 4               8     0.0

# %%
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# 2             STEM          5          NaN             NaN        never
# 3  Business Degree         <1          NaN         Pvt Ltd        never
# 4             STEM        >20        50-99  Funded Startup            4
#
#    training_hours  target
# 0              36     1.0
# 1              47     0.0
# 2              83     0.0
# 3              52     1.0
# 4               8     0.0

# %%
len(df)
# Out:
# 19158

# %%
df
# Out:
#        enrollee_id  city_development_index gender      relevent_experience  \
# 0             8949                   0.920   Male  Has relevent experience
# 1            29725                   0.776   Male   No relevent experience
# 2            11561                   0.624    NaN   No relevent experience
# 3            33241                   0.789    NaN   No relevent experience
# 4              666                   0.767   Male  Has relevent experience
# ...            ...                     ...    ...                      ...
# 19153         7386                   0.878   Male   No relevent experience
# 19154        31398                   0.920   Male  Has relevent experience
# 19155        24576                   0.920   Male  Has relevent experience
# 19156         5756                   0.802   Male  Has relevent experience
# 19157        23834                   0.855    NaN   No relevent experience
#
#       enrolled_university education_level major_discipline experience  \
# 0           no_enrollment        Graduate             STEM        >20
# 1           no_enrollment        Graduate             STEM         15
# 2        Full time course        Graduate             STEM          5
# 3                     NaN        Graduate  Business Degree         <1
# 4           no_enrollment         Masters             STEM        >20
# ...                   ...             ...              ...        ...
# 19153       no_enrollment        Graduate       Humanities         14
# 19154       no_enrollment        Graduate             STEM         14
# 19155       no_enrollment        Graduate             STEM        >20
# 19156       no_enrollment     High School              NaN         <1
# 19157       no_enrollment  Primary School              NaN          2
#
#       company_size    company_type last_new_job  training_hours  target
# 0              NaN             NaN            1              36     1.0
# 1            50-99         Pvt Ltd           >4              47     0.0
# 2              NaN             NaN        never              83     0.0
# 3              NaN         Pvt Ltd        never              52     1.0
# 4            50-99  Funded Startup            4               8     0.0
# ...            ...             ...          ...             ...     ...
# 19153          NaN             NaN            1              42     1.0
# 19154          NaN             NaN            4              52     1.0
# 19155        50-99         Pvt Ltd            4              44     0.0
# 19156      500-999         Pvt Ltd            2              97     0.0
# 19157          NaN             NaN            1             127     0.0
#
# [19158 rows x 13 columns]

# %%
df = pd.read_csv('/content/aug_train.csv')

# %%
df.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours', 'target'],
#       dtype='object')

# %%
df[['enrollee_id', 'city', 'city_development_index', 'gender',
       'relevent_experience', 'enrolled_university', 'education_level',
       'major_discipline', 'experience', 'company_size', 'company_type',
       'last_new_job', 'training_hours', 'target']]
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target
# 0                  36     1.0
# 1                  47     0.0
# 2                  83     0.0
# 3                  52     1.0
# 4                   8     0.0
# ...               ...     ...
# 19153              42     1.0
# 19154              52     1.0
# 19155              44     0.0
# 19156              97     0.0
# 19157             127     0.0
#
# [19158 rows x 14 columns]

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target
# 0                  36     1.0
# 1                  47     0.0
# 2                  83     0.0
# 3                  52     1.0
# 4                   8     0.0
# ...               ...     ...
# 19153              42     1.0
# 19154              52     1.0
# 19155              44     0.0
# 19156              97     0.0
# 19157             127     0.0
#
# [19158 rows x 14 columns]

# %%
df['new_coll']=1

# %%
df['new col2']=df['city_development_index']/3

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target  new coll  new col2
# 0                  36     1.0         1  0.306667
# 1                  47     0.0         1  0.258667
# 2                  83     0.0         1  0.208000
# 3                  52     1.0         1  0.263000
# 4                   8     0.0         1  0.255667
# ...               ...     ...       ...       ...
# 19153              42     1.0         1  0.292667
# 19154              52     1.0         1  0.306667
# 19155              44     0.0         1  0.306667
# 19156              97     0.0         1  0.267333
# 19157             127     0.0         1  0.285000
#
# [19158 rows x 16 columns]

# %%
df.assign(new_col3=99)
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target  new coll  new col2  new_coll  new_col3
# 0                  36     1.0         1  0.306667         1        99
# 1                  47     0.0         1  0.258667         1        99
# 2                  83     0.0         1  0.208000         1        99
# 3                  52     1.0         1  0.263000         1        99
# 4                   8     0.0         1  0.255667         1        99
# ...               ...     ...       ...       ...       ...       ...
# 19153              42     1.0         1  0.292667         1        99
# 19154              52     1.0         1  0.306667         1        99
# 19155              44     0.0         1  0.306667         1        99
# 19156              97     0.0         1  0.267333         1        99
# 19157             127     0.0         1  0.285000         1        99
#
# [19158 rows x 18 columns]

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target  new coll  new col2  new_coll
# 0                  36     1.0         1  0.306667         1
# 1                  47     0.0         1  0.258667         1
# 2                  83     0.0         1  0.208000         1
# 3                  52     1.0         1  0.263000         1
# 4                   8     0.0         1  0.255667         1
# ...               ...     ...       ...       ...       ...
# 19153              42     1.0         1  0.292667         1
# 19154              52     1.0         1  0.306667         1
# 19155              44     0.0         1  0.306667         1
# 19156              97     0.0         1  0.267333         1
# 19157             127     0.0         1  0.285000         1
#
# [19158 rows x 17 columns]

# %%
city_40_female = df[(df['city']=='city_40')&(df['gender']=='Female')].copy()

# %% [markdown]
# filtration

# %%
df.query('city == "city_40" and gender =="Female"')
# Out:
#        enrollee_id     city  city_development_index  gender  \
# 5625         18467  city_40                   0.776  Female
# 6385         11547  city_40                   0.776  Female
# 8032         24409  city_40                   0.776  Female
# 8046         27349  city_40                   0.776  Female
# 9923          6702  city_40                   0.776  Female
# 13871        17684  city_40                   0.776  Female
#
#            relevent_experience enrolled_university education_level  \
# 5625   Has relevent experience       no_enrollment         Masters
# 6385   Has relevent experience       no_enrollment        Graduate
# 8032    No relevent experience       no_enrollment         Masters
# 8046    No relevent experience       no_enrollment         Masters
# 9923    No relevent experience    Full time course        Graduate
# 13871  Has relevent experience       no_enrollment        Graduate
#
#       major_discipline experience company_size company_type last_new_job  \
# 5625              STEM         15    1000-4999      Pvt Ltd            2
# 6385              STEM          2        10/49      Pvt Ltd            1
# 8032              STEM          1          NaN          NaN            1
# 8046              STEM          1        10/49      Pvt Ltd        never
# 9923             Other          1      100-500          NaN            1
# 13871             STEM          5        50-99      Pvt Ltd            1
#
#        training_hours  target  new coll  new col2  new_coll
# 5625               25     0.0         1  0.258667         1
# 6385               15     0.0         1  0.258667         1
# 8032               49     1.0         1  0.258667         1
# 8046               19     1.0         1  0.258667         1
# 9923               34     0.0         1  0.258667         1
# 13871             118     0.0         1  0.258667         1

# %%
city_40_female['new col3'] = 4

# %%
city_40_female
# Out:
#        enrollee_id     city  city_development_index  gender  \
# 5625         18467  city_40                   0.776  Female
# 6385         11547  city_40                   0.776  Female
# 8032         24409  city_40                   0.776  Female
# 8046         27349  city_40                   0.776  Female
# 9923          6702  city_40                   0.776  Female
# 13871        17684  city_40                   0.776  Female
#
#            relevent_experience enrolled_university education_level  \
# 5625   Has relevent experience       no_enrollment         Masters
# 6385   Has relevent experience       no_enrollment        Graduate
# 8032    No relevent experience       no_enrollment         Masters
# 8046    No relevent experience       no_enrollment         Masters
# 9923    No relevent experience    Full time course        Graduate
# 13871  Has relevent experience       no_enrollment        Graduate
#
#       major_discipline experience company_size company_type last_new_job  \
# 5625              STEM         15    1000-4999      Pvt Ltd            2
# 6385              STEM          2        10/49      Pvt Ltd            1
# 8032              STEM          1          NaN          NaN            1
# 8046              STEM          1        10/49      Pvt Ltd        never
# 9923             Other          1      100-500          NaN            1
# 13871             STEM          5        50-99      Pvt Ltd            1
#
#        training_hours  target  new coll  new col2  new_coll  new col3
# 5625               25     0.0         1  0.258667         1         4
# 6385               15     0.0         1  0.258667         1         4
# 8032               49     1.0         1  0.258667         1         4
# 8046               19     1.0         1  0.258667         1         4
# 9923               34     0.0         1  0.258667         1         4
# 13871             118     0.0         1  0.258667         1         4

# %% [markdown]
# Analysis PROPUSKI

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target  new coll  new col2  new_coll
# 0                  36     1.0         1  0.306667         1
# 1                  47     0.0         1  0.258667         1
# 2                  83     0.0         1  0.208000         1
# 3                  52     1.0         1  0.263000         1
# 4                   8     0.0         1  0.255667         1
# ...               ...     ...       ...       ...       ...
# 19153              42     1.0         1  0.292667         1
# 19154              52     1.0         1  0.306667         1
# 19155              44     0.0         1  0.306667         1
# 19156              97     0.0         1  0.267333         1
# 19157             127     0.0         1  0.285000         1
#
# [19158 rows x 17 columns]

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# company_type              0.320493
# company_size              0.309949
# gender                    0.235306
# major_discipline          0.146832
# education_level           0.024011
# last_new_job              0.022080
# enrolled_university       0.020148
# experience                0.003393
# training_hours            0.000000
# new col2                  0.000000
# new coll                  0.000000
# target                    0.000000
# enrollee_id               0.000000
# city                      0.000000
# relevent_experience       0.000000
# city_development_index    0.000000
# new_coll                  0.000000
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
#  14  new coll                19158 non-null  int64
#  15  new col2                19158 non-null  float64
#  16  new_coll                19158 non-null  int64
# dtypes: float64(3), int64(4), object(10)
# memory usage: 2.5+ MB

# %%
df.dtypes
# Out:
# enrollee_id                 int64
# city                       object
# city_development_index    float64
# gender                     object
# relevent_experience        object
# enrolled_university        object
# education_level            object
# major_discipline           object
# experience                 object
# company_size               object
# company_type               object
# last_new_job               object
# training_hours              int64
# target                    float64
# new coll                    int64
# new col2                  float64
# new_coll                    int64
# dtype: object

# %% [markdown]
# Types of variables

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target  new coll  new col2  new_coll
# 0                  36     1.0         1  0.306667         1
# 1                  47     0.0         1  0.258667         1
# 2                  83     0.0         1  0.208000         1
# 3                  52     1.0         1  0.263000         1
# 4                   8     0.0         1  0.255667         1
# ...               ...     ...       ...       ...       ...
# 19153              42     1.0         1  0.292667         1
# 19154              52     1.0         1  0.306667         1
# 19155              44     0.0         1  0.306667         1
# 19156              97     0.0         1  0.267333         1
# 19157             127     0.0         1  0.285000         1
#
# [19158 rows x 17 columns]

# %%
import matplotlib.pyplot as plt


plt.style.use('dark_background')

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df['gender'].hist()
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index  training_hours        target  \
# count  19158.000000            19158.000000    19158.000000  19158.000000
# mean   16875.358179                0.828848       65.366896      0.249348
# std     9616.292592                0.123362       60.058462      0.432647
# min        1.000000                0.448000        1.000000      0.000000
# 25%     8554.250000                0.740000       23.000000      0.000000
# 50%    16982.500000                0.903000       47.000000      0.000000
# 75%    25169.750000                0.920000       88.000000      0.000000
# max    33380.000000                0.949000      336.000000      1.000000
#
#        new coll      new col2  new_coll
# count   19158.0  19158.000000   19158.0
# mean        1.0      0.276283       1.0
# std         0.0      0.041121       0.0
# min         1.0      0.149333       1.0
# 25%         1.0      0.246667       1.0
# 50%         1.0      0.301000       1.0
# 75%         1.0      0.306667       1.0
# max         1.0      0.316333       1.0
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6541663804320280313 = autoviz.get_df('df_6541663804320280313')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_6541663804320280313, *['enrollee_id'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6541663804320280313 = autoviz.get_df('df_6541663804320280313')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_6541663804320280313, *['city_development_index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6541663804320280313 = autoviz.get_df('df_6541663804320280313')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_6541663804320280313, *['training_hours'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6541663804320280313 = autoviz.get_df('df_6541663804320280313')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_6541663804320280313, *['target'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6541663804320280313 = autoviz.get_df('df_6541663804320280313')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_6541663804320280313, *['enrollee_id'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6541663804320280313 = autoviz.get_df('df_6541663804320280313')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_6541663804320280313, *['city_development_index'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6541663804320280313 = autoviz.get_df('df_6541663804320280313')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_6541663804320280313, *['training_hours'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_6541663804320280313 = autoviz.get_df('df_6541663804320280313')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_6541663804320280313, *['target'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_6541663804320280313 = autoviz.get_df('df_6541663804320280313')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_6541663804320280313, *[[['enrollee_id', 'city_development_index'], ['city_development_index', 'training_hours'], ['training_hours', 'target'], ['target', 'new coll']]], **{})
# chart

# %%
df['gender'].value_counts(dropna=False)
# Out:
# Male      13221
# NaN        4508
# Female     1238
# Other       191
# Name: gender, dtype: int64

# %% [markdown]
# Filter By Quantile

# %%
q=df['city_development_index'].quantile(0.25)

# %%
q
# Out:
# 0.74

# %%
len(df[df['city_development_index'] < q]) / len(df)
# Out:
# 0.24903434596513205

# %%
q1=df['city_development_index'].quantile(0.1)
q2=df['city_development_index'].quantile(0.3)

# %%
q=df['city_development_index'].hist()

# %%
df[df['city_development_index'].between(q1,q2)]['city_development_index'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Analysis Data Base SVODNIKI

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target  new coll  new col2  new_coll
# 0                  36     1.0         1  0.306667         1
# 1                  47     0.0         1  0.258667         1
# 2                  83     0.0         1  0.208000         1
# 3                  52     1.0         1  0.263000         1
# 4                   8     0.0         1  0.255667         1
# ...               ...     ...       ...       ...       ...
# 19153              42     1.0         1  0.292667         1
# 19154              52     1.0         1  0.306667         1
# 19155              44     0.0         1  0.306667         1
# 19156              97     0.0         1  0.267333         1
# 19157             127     0.0         1  0.285000         1
#
# [19158 rows x 17 columns]

# %%
df['target'].mean()
# Out:
# 0.24934753105752167

# %%
df.groupby('gender')['target'].mean()
# Out:
# gender
# Female    0.263328
# Male      0.227819
# Other     0.261780
# Name: target, dtype: float64

# %%
t=df.groupby('gender',dropna=False)['target'].agg(['count','mean'])

# %%
t
# Out:
#         count      mean
# gender
# Female   1238  0.263328
# Male    13221  0.227819
# Other     191  0.261780
# NaN      4508  0.308119

# %%
t['count'].sum()
# Out:
# 19158

# %%
df.groupby('education_level',dropna=False)['target'].agg(['count','mean'])
# Out:
#                  count      mean
# education_level
# Graduate         11598  0.279790
# High School       2017  0.195340
# Masters           4361  0.214400
# Phd                414  0.140097
# Primary School     308  0.133117
# NaN                460  0.226087

# %%
df.groupby('education_level',dropna=False)['target'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='education_level'>

# %% [markdown]
# SVODNIKI DLYA NEPRERYVNYH PEREMEN

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size    company_type last_new_job  \
# 0                 STEM        >20          NaN             NaN            1
# 1                 STEM         15        50-99         Pvt Ltd           >4
# 2                 STEM          5          NaN             NaN        never
# 3      Business Degree         <1          NaN         Pvt Ltd        never
# 4                 STEM        >20        50-99  Funded Startup            4
# ...                ...        ...          ...             ...          ...
# 19153       Humanities         14          NaN             NaN            1
# 19154             STEM         14          NaN             NaN            4
# 19155             STEM        >20        50-99         Pvt Ltd            4
# 19156              NaN         <1      500-999         Pvt Ltd            2
# 19157              NaN          2          NaN             NaN            1
#
#        training_hours  target  new coll  new col2  new_coll
# 0                  36     1.0         1  0.306667         1
# 1                  47     0.0         1  0.258667         1
# 2                  83     0.0         1  0.208000         1
# 3                  52     1.0         1  0.263000         1
# 4                   8     0.0         1  0.255667         1
# ...               ...     ...       ...       ...       ...
# 19153              42     1.0         1  0.292667         1
# 19154              52     1.0         1  0.306667         1
# 19155              44     0.0         1  0.306667         1
# 19156              97     0.0         1  0.267333         1
# 19157             127     0.0         1  0.285000         1
#
# [19158 rows x 17 columns]

# %%
df['city_development_index_group'] = pd.cut(df['city_development_index'],5)

# %%
df.groupby('city_development_index_group',dropna=False)['target'].agg(['count','mean'])
# Out:
#                               count      mean
# city_development_index_group
# (0.447, 0.548]                  178  0.578652
# (0.548, 0.648]                 3297  0.582651
# (0.648, 0.749]                 1529  0.273381
# (0.749, 0.849]                 1949  0.194459
# (0.849, 0.949]                12205  0.160262

# %%
df['city_development_index'].hist()
# Out:
# <Axes: >

# %%
df['city_development_index_group'] = pd.qcut(df['city_development_index'],5,duplicates='drop')

# %%
t=df.groupby('city_development_index_group',dropna=False)['target'].agg(['count','mean'])

# %%
t['count'].sum()
# Out:
# 19158

# %%
t['mean'].plot()
# Out:
# <Axes: xlabel='city_development_index_group'>

# %%
df['city_development_index_group_custom'] = pd.cut(df['city_development_index'],
                                      [-float('inf'),0,0.1,0.2,0.5,float('inf')])

# %%
df.groupby('city_development_index_group_custom',dropna=False)['target'].agg(['count','mean'])
# Out:
#                                      count      mean
# city_development_index_group_custom
# (-inf, 0.0]                              0       NaN
# (0.0, 0.1]                               0       NaN
# (0.1, 0.2]                               0       NaN
# (0.2, 0.5]                              63  0.587302
# (0.5, inf]                           19095  0.248233

# %%
df.groupby('education_level',dropna=False)['target'].agg(['count','mean'])
# Out:
#                  count      mean
# education_level
# Graduate         11598  0.279790
# High School       2017  0.195340
# Masters           4361  0.214400
# Phd                414  0.140097
# Primary School     308  0.133117
# NaN                460  0.226087

# %%
def education_group(x):
  if x in ['High School', 'Primary School']:
    return 'School'
  if x in ['Masters', 'Phd']:
    return 'Masters_and_phd'
  if x in ['Graduate']:
    return 'Graduate'
    return x

# %%
df['new_education_level'] = df['education_level'].apply(education_group)

# %%
df.groupby('new_education_level',dropna=False)['target'].agg(['count','mean'])
# Out:
#                      count      mean
# new_education_level
# Graduate             11598  0.279790
# Masters_and_phd       4775  0.207958
# School                2325  0.187097
# NaN                    460  0.226087

# %%
df['education_level'].replace('Primary School','School')
# Out:
# 0           Graduate
# 1           Graduate
# 2           Graduate
# 3           Graduate
# 4            Masters
#             ...
# 19153       Graduate
# 19154       Graduate
# 19155       Graduate
# 19156    High School
# 19157         School
# Name: education_level, Length: 19158, dtype: object

# %%
d={'Primary School' : 'School','High School' : 'School'}

# %%
df['education_level'].map(d)
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 19153       NaN
# 19154       NaN
# 19155       NaN
# 19156    School
# 19157    School
# Name: education_level, Length: 19158, dtype: object

# %% [markdown]
# FUNCTIONS WITH FEW COLUMNS

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size  ... last_new_job  \
# 0                 STEM        >20          NaN  ...            1
# 1                 STEM         15        50-99  ...           >4
# 2                 STEM          5          NaN  ...        never
# 3      Business Degree         <1          NaN  ...        never
# 4                 STEM        >20        50-99  ...            4
# ...                ...        ...          ...  ...          ...
# 19153       Humanities         14          NaN  ...            1
# 19154             STEM         14          NaN  ...            4
# 19155             STEM        >20        50-99  ...            4
# 19156              NaN         <1      500-999  ...            2
# 19157              NaN          2          NaN  ...            1
#
#       training_hours  target  new coll  new col2  new_coll  \
# 0                 36     1.0         1  0.306667         1
# 1                 47     0.0         1  0.258667         1
# 2                 83     0.0         1  0.208000         1
# 3                 52     1.0         1  0.263000         1
# 4                  8     0.0         1  0.255667         1
# ...              ...     ...       ...       ...       ...
# 19153             42     1.0         1  0.292667         1
# 19154             52     1.0         1  0.306667         1
# 19155             44     0.0         1  0.306667         1
# 19156             97     0.0         1  0.267333         1
# 19157            127     0.0         1  0.285000         1
#
#        city_development_index_group city_development_index_group_custom  \
# 0                     (0.878, 0.92]                          (0.5, inf]
# 1                    (0.691, 0.878]                          (0.5, inf]
# 2                    (0.447, 0.691]                          (0.5, inf]
# 3                    (0.691, 0.878]                          (0.5, inf]
# 4                    (0.691, 0.878]                          (0.5, inf]
# ...                             ...                                 ...
# 19153                (0.691, 0.878]                          (0.5, inf]
# 19154                 (0.878, 0.92]                          (0.5, inf]
# 19155                 (0.878, 0.92]                          (0.5, inf]
# 19156                (0.691, 0.878]                          (0.5, inf]
# 19157                (0.691, 0.878]                          (0.5, inf]
#
#       new_education_group new_education_level
# 0                    None            Graduate
# 1                    None            Graduate
# 2                    None            Graduate
# 3                    None            Graduate
# 4         Masters_and_phd     Masters_and_phd
# ...                   ...                 ...
# 19153                None            Graduate
# 19154                None            Graduate
# 19155                None            Graduate
# 19156              School              School
# 19157              School              School
#
# [19158 rows x 21 columns]

# %%
def new_training_hours(row):
  if row['education_level'] == 'Phd':
    return row['training_hours'] + 1000
    return row['training_hours']

# %%
 df['new_training_hours'] = df.apply(new_training_hours,axis=1)

# %%
df[df['education_level'] == 'Phd']
# Out:
#        enrollee_id      city  city_development_index gender  \
# 37           10164  city_114                   0.926   Male
# 121          13915   city_16                   0.910   Male
# 130           3921   city_36                   0.893    NaN
# 135          23947  city_103                   0.920    NaN
# 152          31786  city_103                   0.920   Male
# ...            ...       ...                     ...    ...
# 18738         1477  city_162                   0.767   Male
# 18800        18365  city_103                   0.920   Male
# 18807          229  city_114                   0.926   Male
# 18944         2678  city_104                   0.924    NaN
# 19044        14441   city_89                   0.925   Male
#
#            relevent_experience enrolled_university education_level  \
# 37     Has relevent experience       no_enrollment             Phd
# 121    Has relevent experience       no_enrollment             Phd
# 130     No relevent experience       no_enrollment             Phd
# 135     No relevent experience       no_enrollment             Phd
# 152     No relevent experience       no_enrollment             Phd
# ...                        ...                 ...             ...
# 18738  Has relevent experience       no_enrollment             Phd
# 18800  Has relevent experience       no_enrollment             Phd
# 18807   No relevent experience       no_enrollment             Phd
# 18944   No relevent experience       no_enrollment             Phd
# 19044  Has relevent experience       no_enrollment             Phd
#
#       major_discipline experience company_size  ... training_hours target  \
# 37                STEM        >20      100-500  ...             42    1.0
# 121               STEM        >20      100-500  ...             20    1.0
# 130               STEM        >20    1000-4999  ...              4    0.0
# 135               STEM        NaN          NaN  ...             70    0.0
# 152               STEM        >20        50-99  ...             14    0.0
# ...                ...        ...          ...  ...            ...    ...
# 18738             STEM        >20       10000+  ...             34    0.0
# 18800             STEM         15        50-99  ...            108    0.0
# 18807             STEM         14    5000-9999  ...              9    1.0
# 18944             STEM        >20        50-99  ...             27    0.0
# 19044             STEM          6        50-99  ...            105    0.0
#
#        new coll  new col2  new_coll  city_development_index_group  \
# 37            1  0.308667         1                 (0.92, 0.949]
# 121           1  0.303333         1                 (0.878, 0.92]
# 130           1  0.297667         1                 (0.878, 0.92]
# 135           1  0.306667         1                 (0.878, 0.92]
# 152           1  0.306667         1                 (0.878, 0.92]
# ...         ...       ...       ...                           ...
# 18738         1  0.255667         1                (0.691, 0.878]
# 18800         1  0.306667         1                 (0.878, 0.92]
# 18807         1  0.308667         1                 (0.92, 0.949]
# 18944         1  0.308000         1                 (0.92, 0.949]
# 19044         1  0.308333         1                 (0.92, 0.949]
#
#        city_development_index_group_custom new_education_group  \
# 37                              (0.5, inf]     Masters_and_phd
# 121                             (0.5, inf]     Masters_and_phd
# 130                             (0.5, inf]     Masters_and_phd
# 135                             (0.5, inf]     Masters_and_phd
# 152                             (0.5, inf]     Masters_and_phd
# ...                                    ...                 ...
# 18738                           (0.5, inf]     Masters_and_phd
# 18800                           (0.5, inf]     Masters_and_phd
# 18807                           (0.5, inf]     Masters_and_phd
# 18944                           (0.5, inf]     Masters_and_phd
# 19044                           (0.5, inf]     Masters_and_phd
#
#       new_education_level new_training_hours
# 37        Masters_and_phd             1042.0
# 121       Masters_and_phd             1020.0
# 130       Masters_and_phd             1004.0
# 135       Masters_and_phd             1070.0
# 152       Masters_and_phd             1014.0
# ...                   ...                ...
# 18738     Masters_and_phd             1034.0
# 18800     Masters_and_phd             1108.0
# 18807     Masters_and_phd             1009.0
# 18944     Masters_and_phd             1027.0
# 19044     Masters_and_phd             1105.0
#
# [414 rows x 22 columns]

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size  ... training_hours target  \
# 0                 STEM        >20          NaN  ...             36    1.0
# 1                 STEM         15        50-99  ...             47    0.0
# 2                 STEM          5          NaN  ...             83    0.0
# 3      Business Degree         <1          NaN  ...             52    1.0
# 4                 STEM        >20        50-99  ...              8    0.0
# ...                ...        ...          ...  ...            ...    ...
# 19153       Humanities         14          NaN  ...             42    1.0
# 19154             STEM         14          NaN  ...             52    1.0
# 19155             STEM        >20        50-99  ...             44    0.0
# 19156              NaN         <1      500-999  ...             97    0.0
# 19157              NaN          2          NaN  ...            127    0.0
#
#        new coll  new col2  new_coll  city_development_index_group  \
# 0             1  0.306667         1                 (0.878, 0.92]
# 1             1  0.258667         1                (0.691, 0.878]
# 2             1  0.208000         1                (0.447, 0.691]
# 3             1  0.263000         1                (0.691, 0.878]
# 4             1  0.255667         1                (0.691, 0.878]
# ...         ...       ...       ...                           ...
# 19153         1  0.292667         1                (0.691, 0.878]
# 19154         1  0.306667         1                 (0.878, 0.92]
# 19155         1  0.306667         1                 (0.878, 0.92]
# 19156         1  0.267333         1                (0.691, 0.878]
# 19157         1  0.285000         1                (0.691, 0.878]
#
#        city_development_index_group_custom new_education_group  \
# 0                               (0.5, inf]                None
# 1                               (0.5, inf]                None
# 2                               (0.5, inf]                None
# 3                               (0.5, inf]                None
# 4                               (0.5, inf]     Masters_and_phd
# ...                                    ...                 ...
# 19153                           (0.5, inf]                None
# 19154                           (0.5, inf]                None
# 19155                           (0.5, inf]                None
# 19156                           (0.5, inf]              School
# 19157                           (0.5, inf]              School
#
#       new_education_level new_training_hours
# 0                Graduate                NaN
# 1                Graduate                NaN
# 2                Graduate                NaN
# 3                Graduate                NaN
# 4         Masters_and_phd                NaN
# ...                   ...                ...
# 19153            Graduate                NaN
# 19154            Graduate                NaN
# 19155            Graduate                NaN
# 19156              School                NaN
# 19157              School                NaN
#
# [19158 rows x 22 columns]

# %% [markdown]
# PIVOT TABLE

# %%
df.groupby('new_education_level',dropna=False)['target'].agg(['count','mean'])
# Out:
#                      count      mean
# new_education_level
# Graduate             11598  0.279790
# Masters_and_phd       4775  0.207958
# School                2325  0.187097
# NaN                    460  0.226087

# %%
df.pivot_table(index='new_education_level',values='target',aggfunc=['count','mean'])
# Out:
#                      count      mean
#                     target    target
# new_education_level
# Graduate             11598  0.279790
# Masters_and_phd       4775  0.207958
# School                2325  0.187097

# %%
df['new_education_level'] = df['new_education_level'].fillna('no_info')

# %%
t=df.pivot_table(index='new_education_level',values='target',aggfunc=['count','mean'])

# %%
t
# Out:
#                      count      mean
#                     target    target
# new_education_level
# Graduate             11598  0.279790
# Masters_and_phd       4775  0.207958
# School                2325  0.187097
# no_info                460  0.226087

# %%
t.reset_index()
# Out:
#   new_education_level  count      mean
#                       target    target
# 0            Graduate  11598  0.279790
# 1     Masters_and_phd   4775  0.207958
# 2              School   2325  0.187097
# 3             no_info    460  0.226087

# %%
t.columns = ['_'.join(col).strip() for col in t.columns.values]

# %%
t
# Out:
#                      count_target  mean_target
# new_education_level
# Graduate                    11598     0.279790
# Masters_and_phd              4775     0.207958
# School                       2325     0.187097
# no_info                       460     0.226087

# %%
t=t.reset_index()

# %%
t
# Out:
#   new_education_level  count_target  mean_target
# 0            Graduate         11598     0.279790
# 1     Masters_and_phd          4775     0.207958
# 2              School          2325     0.187097
# 3             no_info           460     0.226087

# %%
df.pivot_table(index='new_education_level',columns='gender',values='target',aggfunc=['count','mean'])
# Out:
#                      count                  mean
# gender              Female  Male Other    Female      Male     Other
# new_education_level
# Graduate               773  8144   112  0.279431  0.257122  0.330357
# Masters_and_phd        386  3237    31  0.233161  0.186284  0.096774
# School                  71  1598    39  0.267606  0.171464  0.205128
# no_info                  8   242     9  0.125000  0.169421  0.222222

# %%
df.groupby(['new_education_level','gender'],
           dropna=False)['target'].agg(['count','mean'])
# Out:
#                             count      mean
# new_education_level gender
# Graduate            Female    773  0.279431
#                     Male     8144  0.257122
#                     Other     112  0.330357
#                     NaN      2569  0.349552
# Masters_and_phd     Female    386  0.233161
#                     Male     3237  0.186284
#                     Other      31  0.096774
#                     NaN      1121  0.264942
# School              Female     71  0.267606
#                     Male     1598  0.171464
#                     Other      39  0.205128
#                     NaN       617  0.217180
# no_info             Female      8  0.125000
#                     Male      242  0.169421
#                     Other       9  0.222222
#                     NaN       201  0.298507

# %%
df.groupby('new_education_level',dropna=False)[
    ['target','city_development_index']].agg(['count','mean'])
# Out:
#                     target           city_development_index
#                      count      mean                  count      mean
# new_education_level
# Graduate             11598  0.279790                  11598  0.823731
# Masters_and_phd       4775  0.207958                   4775  0.840032
# School                2325  0.187097                   2325  0.836080
# no_info                460  0.226087                    460  0.805207

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size  ... training_hours target  \
# 0                 STEM        >20          NaN  ...             36    1.0
# 1                 STEM         15        50-99  ...             47    0.0
# 2                 STEM          5          NaN  ...             83    0.0
# 3      Business Degree         <1          NaN  ...             52    1.0
# 4                 STEM        >20        50-99  ...              8    0.0
# ...                ...        ...          ...  ...            ...    ...
# 19153       Humanities         14          NaN  ...             42    1.0
# 19154             STEM         14          NaN  ...             52    1.0
# 19155             STEM        >20        50-99  ...             44    0.0
# 19156              NaN         <1      500-999  ...             97    0.0
# 19157              NaN          2          NaN  ...            127    0.0
#
#        new coll  new col2  new_coll  city_development_index_group  \
# 0             1  0.306667         1                 (0.878, 0.92]
# 1             1  0.258667         1                (0.691, 0.878]
# 2             1  0.208000         1                (0.447, 0.691]
# 3             1  0.263000         1                (0.691, 0.878]
# 4             1  0.255667         1                (0.691, 0.878]
# ...         ...       ...       ...                           ...
# 19153         1  0.292667         1                (0.691, 0.878]
# 19154         1  0.306667         1                 (0.878, 0.92]
# 19155         1  0.306667         1                 (0.878, 0.92]
# 19156         1  0.267333         1                (0.691, 0.878]
# 19157         1  0.285000         1                (0.691, 0.878]
#
#        city_development_index_group_custom new_education_group  \
# 0                               (0.5, inf]                None
# 1                               (0.5, inf]                None
# 2                               (0.5, inf]                None
# 3                               (0.5, inf]                None
# 4                               (0.5, inf]     Masters_and_phd
# ...                                    ...                 ...
# 19153                           (0.5, inf]                None
# 19154                           (0.5, inf]                None
# 19155                           (0.5, inf]                None
# 19156                           (0.5, inf]              School
# 19157                           (0.5, inf]              School
#
#       new_education_level new_training_hours
# 0                Graduate                NaN
# 1                Graduate                NaN
# 2                Graduate                NaN
# 3                Graduate                NaN
# 4         Masters_and_phd                NaN
# ...                   ...                ...
# 19153            Graduate                NaN
# 19154            Graduate                NaN
# 19155            Graduate                NaN
# 19156              School                NaN
# 19157              School                NaN
#
# [19158 rows x 22 columns]

# %%
t = df.groupby('new_education_level',dropna=False)[
    ['target','city_development_index']].agg(['count','mean']).reset_index()

# %% [markdown]
# HEAT MAP

# %%
df['gender'] = df['gender'].fillna('no_info')

# %%
t=df.pivot_table(index='new_education_level',
               columns='gender',values='target',aggfunc=['mean'])

# %%
t
# Out:
#                          mean
# gender                 Female      Male     Other   no_info
# new_education_level
# Graduate             0.279431  0.257122  0.330357  0.349552
# Masters_and_phd      0.233161  0.186284  0.096774  0.264942
# School               0.267606  0.171464  0.205128  0.217180
# no_info              0.125000  0.169421  0.222222  0.298507

# %%
import seaborn as sns

# %%
sns.heatmap(t)
# Out:
# <Axes: xlabel='None-gender', ylabel='new_education_level'>

# %%
df.pivot_table(index='new_education_level',
               columns='gender',values='target',aggfunc=['count'])
# Out:
#                      count
# gender              Female  Male Other no_info
# new_education_level
# Graduate               773  8144   112    2569
# Masters_and_phd        386  3237    31    1121
# School                  71  1598    39     617
# no_info                  8   242     9     201

# %% [markdown]
# CORRELATION AND PHIK

# %%
df.columns
# Out:
# Index(['enrollee_id', 'city', 'city_development_index', 'gender',
#        'relevent_experience', 'enrolled_university', 'education_level',
#        'major_discipline', 'experience', 'company_size', 'company_type',
#        'last_new_job', 'training_hours', 'target', 'new coll', 'new col2',
#        'new_coll', 'city_development_index_group',
#        'city_development_index_group_custom', 'new_education_group',
#        'new_education_level', 'new_training_hours'],
#       dtype='object')

# %%
df[['city_development_index','training_hours','target']].corr()
# Out:
#                         city_development_index  training_hours    target
# city_development_index                1.000000        0.001920 -0.341665
# training_hours                        0.001920        1.000000 -0.021577
# target                               -0.341665       -0.021577  1.000000

# %%
sns.heatmap(df[['city_development_index','training_hours','target']].corr())
# Out:
# <Axes: >

# %%
pip install phik
# Out:
# Collecting phik
#   Downloading phik-0.12.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (679 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from phik) (1.22.4)
# Requirement already satisfied: scipy>=1.5.2 in /usr/local/lib/python3.10/dist-packages (from phik) (1.10.1)
# Requirement already satisfied: pandas>=0.25.1 in /usr/local/lib/python3.10/dist-packages (from phik) (1.5.3)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.10/dist-packages (from phik) (3.7.1)
# Requirement already satisfied: joblib>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from phik) (1.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.2.3->phik) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25.1->phik) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.2.3->phik) (1.16.0)
# Installing collected packages: phik
# Successfully installed phik-0.12.3

# %%
import phik
from phik.report import plot_correlation_matrix
from phik import report

# %%
phik_overview = df.phik_matrix()
# Out:
# interval columns not set, guessing: ['enrollee_id', 'city_development_index', 'training_hours', 'target', 'new coll', 'new col2', 'new_coll', 'new_training_hours']
# /usr/local/lib/python3.10/dist-packages/phik/data_quality.py:72: UserWarning: Not enough unique value for variable new coll for analysis 1. Dropping this column
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/phik/data_quality.py:72: UserWarning: Not enough unique value for variable new_coll for analysis 1. Dropping this column
#   warnings.warn(

# %%
sns.heatmap(phik_overview)
# Out:
# <Axes: >

# %%
phik_overview['target'].sort_values(ascending=False)
# Out:
# target                                 1.000000
# city_development_index_group           0.523691
# city_development_index                 0.482287
# new col2                               0.482287
# city                                   0.477283
# experience                             0.238725
# relevent_experience                    0.199859
# new_education_level                    0.132478
# gender                                 0.116653
# last_new_job                           0.114708
# enrolled_university                    0.093803
# education_level                        0.075999
# company_size                           0.071953
# enrollee_id                            0.067472
# company_type                           0.066792
# city_development_index_group_custom    0.035805
# new_education_group                    0.032851
# major_discipline                       0.029200
# training_hours                         0.026849
# new_training_hours                     0.000000
# Name: target, dtype: float64

# %% [markdown]
# Check the connection

# %%
df['city_development_index_group']
# Out:
# 0         (0.878, 0.92]
# 1        (0.691, 0.878]
# 2        (0.447, 0.691]
# 3        (0.691, 0.878]
# 4        (0.691, 0.878]
#               ...
# 19153    (0.691, 0.878]
# 19154     (0.878, 0.92]
# 19155     (0.878, 0.92]
# 19156    (0.691, 0.878]
# 19157    (0.691, 0.878]
# Name: city_development_index_group, Length: 19158, dtype: category
# Categories (4, interval[float64, right]): [(0.447, 0.691] < (0.691, 0.878] < (0.878, 0.92] <
#                                            (0.92, 0.949]]

# %%
df.groupby('city_development_index_group')['target'].agg(['count','mean'])
# Out:
#                               count      mean
# city_development_index_group
# (0.447, 0.691]                 3869  0.550530
# (0.691, 0.878]                 3827  0.206428
# (0.878, 0.92]                  8925  0.178375
# (0.92, 0.949]                  2537  0.104454

# %%
t=df.groupby('city')['target'].agg(['count','mean'])

# %%
t
# Out:
#           count      mean
# city
# city_1       26  0.115385
# city_10      86  0.104651
# city_100    275  0.236364
# city_101     75  0.573333
# city_102    304  0.171053
# ...         ...       ...
# city_93      26  0.192308
# city_94      26  0.384615
# city_97     104  0.076923
# city_98      79  0.101266
# city_99      94  0.159574
#
# [123 rows x 2 columns]

# %%
t.sort_values('count',ascending=False).head(10)['mean'].plot(kind='bar')
# Out:
# <Axes: xlabel='city'>

# %%
t=df.groupby('city')[['target','city_development_index']].agg(['count','mean'])

# %%
t.columns = ['_'.join(col).strip() for col in t.columns.values]

# %%
t.sort_values('target_count',ascending=False).head(10)
# Out:
#           target_count  target_mean  city_development_index_count  \
# city
# city_103          4355     0.213088                          4355
# city_21           2702     0.591044                          2702
# city_16           1533     0.116765                          1533
# city_114          1336     0.099551                          1336
# city_160           845     0.235503                           845
# city_136           586     0.104096                           586
# city_67            431     0.132251                           431
# city_75            305     0.101639                           305
# city_102           304     0.171053                           304
# city_104           301     0.093023                           301
#
#           city_development_index_mean
# city
# city_103                        0.920
# city_21                         0.624
# city_16                         0.910
# city_114                        0.926
# city_160                        0.920
# city_136                        0.897
# city_67                         0.855
# city_75                         0.939
# city_102                        0.804
# city_104                        0.924

# %%
df['experience_int'] = df[
    'experience'].replace('<1', '0').replace('>20', '999').fillna(-1).astype(int)

# %%
df['experience_group'] = pd.qcut(df['experience_int'],5)

# %%
df.groupby('experience_group')['target'].agg(['count','mean'])
# Out:
#                   count      mean
# experience_group
# (-1.001, 4.0]      5020  0.358964
# (4.0, 6.0]         2646  0.285336
# (6.0, 11.0]        4459  0.239740
# (11.0, 18.0]       3295  0.170561
# (18.0, 999.0]      3738  0.157571

# %%
df.groupby('experience_group')['target'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='experience_group'>

# %% [markdown]
# igrushechnye dannye

# %%
t = pd.DataFrame({'col1':[1,2,3,float('nan')],
                  'col2':['a','b','c','d'],
                  'col3':[0]*3 + [1]*1})

# %%
t
# Out:
#    col1 col2
# 0   1.0    a
# 1   2.0    b
# 2   3.0    c
# 3   NaN    d

# %% [markdown]
# Function aggregation

# %%
t['col1'].sum()
# Out:
# 6.0

# %%
t['col1'].mean()
# Out:
# 2.0

# %%
t['col2'].count()
# Out:
# 4

# %%
len(t)
# Out:
# 4

# %% [markdown]
# VISUALIZATION BASE

# %%
df['city_development_index'].hist(bins=20)
# Out:
# <Axes: >

# %%
df['gender'].value_counts()
# Out:
# Male       13221
# no_info     4508
# Female      1238
# Other        191
# Name: gender, dtype: int64

# %%
df['gender'].hist()
# Out:
# <Axes: >

# %%
df['gender'].replace('no_info',float('nan'))
# Out:
# 0        Male
# 1        Male
# 2         NaN
# 3         NaN
# 4        Male
#          ...
# 19153    Male
# 19154    Male
# 19155    Male
# 19156    Male
# 19157     NaN
# Name: gender, Length: 19158, dtype: object

# %%
df['gender'].hist()
# Out:
# <Axes: >

# %%
df['gender'].value_counts(dropna=False).plot(kind='bar')
# Out:
# <Axes: >

# %%
df.groupby('education_level',dropna=False)['target'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='education_level'>

# %% [markdown]
# Scatter Plot

# %%
t=pd.DataFrame({'x':[1,2,3],'y':[1,2,3]})

# %%
t.plot(x='x', y='y', kind='scatter', )
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
df
# Out:
#        enrollee_id      city  city_development_index   gender  \
# 0             8949  city_103                   0.920     Male
# 1            29725   city_40                   0.776     Male
# 2            11561   city_21                   0.624  no_info
# 3            33241  city_115                   0.789  no_info
# 4              666  city_162                   0.767     Male
# ...            ...       ...                     ...      ...
# 19153         7386  city_173                   0.878     Male
# 19154        31398  city_103                   0.920     Male
# 19155        24576  city_103                   0.920     Male
# 19156         5756   city_65                   0.802     Male
# 19157        23834   city_67                   0.855  no_info
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size  ... new coll  new col2  \
# 0                 STEM        >20          NaN  ...        1  0.306667
# 1                 STEM         15        50-99  ...        1  0.258667
# 2                 STEM          5          NaN  ...        1  0.208000
# 3      Business Degree         <1          NaN  ...        1  0.263000
# 4                 STEM        >20        50-99  ...        1  0.255667
# ...                ...        ...          ...  ...      ...       ...
# 19153       Humanities         14          NaN  ...        1  0.292667
# 19154             STEM         14          NaN  ...        1  0.306667
# 19155             STEM        >20        50-99  ...        1  0.306667
# 19156              NaN         <1      500-999  ...        1  0.267333
# 19157              NaN          2          NaN  ...        1  0.285000
#
#        new_coll  city_development_index_group  \
# 0             1                 (0.878, 0.92]
# 1             1                (0.691, 0.878]
# 2             1                (0.447, 0.691]
# 3             1                (0.691, 0.878]
# 4             1                (0.691, 0.878]
# ...         ...                           ...
# 19153         1                (0.691, 0.878]
# 19154         1                 (0.878, 0.92]
# 19155         1                 (0.878, 0.92]
# 19156         1                (0.691, 0.878]
# 19157         1                (0.691, 0.878]
#
#        city_development_index_group_custom  new_education_group  \
# 0                               (0.5, inf]                 None
# 1                               (0.5, inf]                 None
# 2                               (0.5, inf]                 None
# 3                               (0.5, inf]                 None
# 4                               (0.5, inf]      Masters_and_phd
# ...                                    ...                  ...
# 19153                           (0.5, inf]                 None
# 19154                           (0.5, inf]                 None
# 19155                           (0.5, inf]                 None
# 19156                           (0.5, inf]               School
# 19157                           (0.5, inf]               School
#
#        new_education_level new_training_hours experience_int experience_group
# 0                 Graduate                NaN            999    (18.0, 999.0]
# 1                 Graduate                NaN             15     (11.0, 18.0]
# 2                 Graduate                NaN              5       (4.0, 6.0]
# 3                 Graduate                NaN              0    (-1.001, 4.0]
# 4          Masters_and_phd                NaN            999    (18.0, 999.0]
# ...                    ...                ...            ...              ...
# 19153             Graduate                NaN             14     (11.0, 18.0]
# 19154             Graduate                NaN             14     (11.0, 18.0]
# 19155             Graduate                NaN            999    (18.0, 999.0]
# 19156               School                NaN              0    (-1.001, 4.0]
# 19157               School                NaN              2    (-1.001, 4.0]
#
# [19158 rows x 24 columns]

# %%
df[df['experience_int']<999].plot(
    x='city_development_index', y='experience_int',kind='scatter',alpha=0.1)
# Out:
# <Axes: xlabel='city_development_index', ylabel='experience_int'>

# %%
df
# Out:
#        enrollee_id      city  city_development_index   gender  \
# 0             8949  city_103                   0.920     Male
# 1            29725   city_40                   0.776     Male
# 2            11561   city_21                   0.624  no_info
# 3            33241  city_115                   0.789  no_info
# 4              666  city_162                   0.767     Male
# ...            ...       ...                     ...      ...
# 19153         7386  city_173                   0.878     Male
# 19154        31398  city_103                   0.920     Male
# 19155        24576  city_103                   0.920     Male
# 19156         5756   city_65                   0.802     Male
# 19157        23834   city_67                   0.855  no_info
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size  ... new coll  new col2  \
# 0                 STEM        >20          NaN  ...        1  0.306667
# 1                 STEM         15        50-99  ...        1  0.258667
# 2                 STEM          5          NaN  ...        1  0.208000
# 3      Business Degree         <1          NaN  ...        1  0.263000
# 4                 STEM        >20        50-99  ...        1  0.255667
# ...                ...        ...          ...  ...      ...       ...
# 19153       Humanities         14          NaN  ...        1  0.292667
# 19154             STEM         14          NaN  ...        1  0.306667
# 19155             STEM        >20        50-99  ...        1  0.306667
# 19156              NaN         <1      500-999  ...        1  0.267333
# 19157              NaN          2          NaN  ...        1  0.285000
#
#        new_coll  city_development_index_group  \
# 0             1                 (0.878, 0.92]
# 1             1                (0.691, 0.878]
# 2             1                (0.447, 0.691]
# 3             1                (0.691, 0.878]
# 4             1                (0.691, 0.878]
# ...         ...                           ...
# 19153         1                (0.691, 0.878]
# 19154         1                 (0.878, 0.92]
# 19155         1                 (0.878, 0.92]
# 19156         1                (0.691, 0.878]
# 19157         1                (0.691, 0.878]
#
#        city_development_index_group_custom  new_education_group  \
# 0                               (0.5, inf]                 None
# 1                               (0.5, inf]                 None
# 2                               (0.5, inf]                 None
# 3                               (0.5, inf]                 None
# 4                               (0.5, inf]      Masters_and_phd
# ...                                    ...                  ...
# 19153                           (0.5, inf]                 None
# 19154                           (0.5, inf]                 None
# 19155                           (0.5, inf]                 None
# 19156                           (0.5, inf]               School
# 19157                           (0.5, inf]               School
#
#        new_education_level new_training_hours experience_int experience_group
# 0                 Graduate                NaN            999    (18.0, 999.0]
# 1                 Graduate                NaN             15     (11.0, 18.0]
# 2                 Graduate                NaN              5       (4.0, 6.0]
# 3                 Graduate                NaN              0    (-1.001, 4.0]
# 4          Masters_and_phd                NaN            999    (18.0, 999.0]
# ...                    ...                ...            ...              ...
# 19153             Graduate                NaN             14     (11.0, 18.0]
# 19154             Graduate                NaN             14     (11.0, 18.0]
# 19155             Graduate                NaN            999    (18.0, 999.0]
# 19156               School                NaN              0    (-1.001, 4.0]
# 19157               School                NaN              2    (-1.001, 4.0]
#
# [19158 rows x 24 columns]

# %%
(df[df['experience_int']<999]
.groupby('city_development_index_group')
['experience_int'].agg(['count','mean','median']))
# Out:
#                               count      mean  median
# city_development_index_group
# (0.447, 0.691]                 3768  5.603238     5.0
# (0.691, 0.878]                 3408  7.936620     7.0
# (0.878, 0.92]                  6733  8.576860     8.0
# (0.92, 0.949]                  1963  9.099338     9.0

# %%
(df[df['experience_int']<999]
.groupby('city_development_index_group')
['experience_int'].mean()).plot()
# Out:
# <Axes: xlabel='city_development_index_group'>

# %% [markdown]
# Joins

# %%
df
# Out:
#        enrollee_id      city  city_development_index   gender  \
# 0             8949  city_103                   0.920     Male
# 1            29725   city_40                   0.776     Male
# 2            11561   city_21                   0.624  no_info
# 3            33241  city_115                   0.789  no_info
# 4              666  city_162                   0.767     Male
# ...            ...       ...                     ...      ...
# 19153         7386  city_173                   0.878     Male
# 19154        31398  city_103                   0.920     Male
# 19155        24576  city_103                   0.920     Male
# 19156         5756   city_65                   0.802     Male
# 19157        23834   city_67                   0.855  no_info
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size  ... new coll  new col2  \
# 0                 STEM        >20          NaN  ...        1  0.306667
# 1                 STEM         15        50-99  ...        1  0.258667
# 2                 STEM          5          NaN  ...        1  0.208000
# 3      Business Degree         <1          NaN  ...        1  0.263000
# 4                 STEM        >20        50-99  ...        1  0.255667
# ...                ...        ...          ...  ...      ...       ...
# 19153       Humanities         14          NaN  ...        1  0.292667
# 19154             STEM         14          NaN  ...        1  0.306667
# 19155             STEM        >20        50-99  ...        1  0.306667
# 19156              NaN         <1      500-999  ...        1  0.267333
# 19157              NaN          2          NaN  ...        1  0.285000
#
#        new_coll  city_development_index_group  \
# 0             1                 (0.878, 0.92]
# 1             1                (0.691, 0.878]
# 2             1                (0.447, 0.691]
# 3             1                (0.691, 0.878]
# 4             1                (0.691, 0.878]
# ...         ...                           ...
# 19153         1                (0.691, 0.878]
# 19154         1                 (0.878, 0.92]
# 19155         1                 (0.878, 0.92]
# 19156         1                (0.691, 0.878]
# 19157         1                (0.691, 0.878]
#
#        city_development_index_group_custom  new_education_group  \
# 0                               (0.5, inf]                 None
# 1                               (0.5, inf]                 None
# 2                               (0.5, inf]                 None
# 3                               (0.5, inf]                 None
# 4                               (0.5, inf]      Masters_and_phd
# ...                                    ...                  ...
# 19153                           (0.5, inf]                 None
# 19154                           (0.5, inf]                 None
# 19155                           (0.5, inf]                 None
# 19156                           (0.5, inf]               School
# 19157                           (0.5, inf]               School
#
#        new_education_level new_training_hours experience_int experience_group
# 0                 Graduate                NaN            999    (18.0, 999.0]
# 1                 Graduate                NaN             15     (11.0, 18.0]
# 2                 Graduate                NaN              5       (4.0, 6.0]
# 3                 Graduate                NaN              0    (-1.001, 4.0]
# 4          Masters_and_phd                NaN            999    (18.0, 999.0]
# ...                    ...                ...            ...              ...
# 19153             Graduate                NaN             14     (11.0, 18.0]
# 19154             Graduate                NaN             14     (11.0, 18.0]
# 19155             Graduate                NaN            999    (18.0, 999.0]
# 19156               School                NaN              0    (-1.001, 4.0]
# 19157               School                NaN              2    (-1.001, 4.0]
#
# [19158 rows x 24 columns]

# %%
df[['enrollee_id']]
# Out:
#        enrollee_id
# 0             8949
# 1            29725
# 2            11561
# 3            33241
# 4              666
# ...            ...
# 19153         7386
# 19154        31398
# 19155        24576
# 19156         5756
# 19157        23834
#
# [19158 rows x 1 columns]

# %%
age = df[['enrollee_id']].copy()

# %%
age['age']=30

# %%
age
# Out:
#        enrollee_id  age
# 0             8949   30
# 1            29725   30
# 2            11561   30
# 3            33241   30
# 4              666   30
# ...            ...  ...
# 19153         7386   30
# 19154        31398   30
# 19155        24576   30
# 19156         5756   30
# 19157        23834   30
#
# [19158 rows x 2 columns]

# %%
df = df.merge(age,how='left',on='enrollee_id')

# %%
df
# Out:
#        enrollee_id      city  city_development_index   gender  \
# 0             8949  city_103                   0.920     Male
# 1            29725   city_40                   0.776     Male
# 2            11561   city_21                   0.624  no_info
# 3            33241  city_115                   0.789  no_info
# 4              666  city_162                   0.767     Male
# ...            ...       ...                     ...      ...
# 19153         7386  city_173                   0.878     Male
# 19154        31398  city_103                   0.920     Male
# 19155        24576  city_103                   0.920     Male
# 19156         5756   city_65                   0.802     Male
# 19157        23834   city_67                   0.855  no_info
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# 2       No relevent experience    Full time course        Graduate
# 3       No relevent experience                 NaN        Graduate
# 4      Has relevent experience       no_enrollment         Masters
# ...                        ...                 ...             ...
# 19153   No relevent experience       no_enrollment        Graduate
# 19154  Has relevent experience       no_enrollment        Graduate
# 19155  Has relevent experience       no_enrollment        Graduate
# 19156  Has relevent experience       no_enrollment     High School
# 19157   No relevent experience       no_enrollment  Primary School
#
#       major_discipline experience company_size  ...  new col2 new_coll  \
# 0                 STEM        >20          NaN  ...  0.306667        1
# 1                 STEM         15        50-99  ...  0.258667        1
# 2                 STEM          5          NaN  ...  0.208000        1
# 3      Business Degree         <1          NaN  ...  0.263000        1
# 4                 STEM        >20        50-99  ...  0.255667        1
# ...                ...        ...          ...  ...       ...      ...
# 19153       Humanities         14          NaN  ...  0.292667        1
# 19154             STEM         14          NaN  ...  0.306667        1
# 19155             STEM        >20        50-99  ...  0.306667        1
# 19156              NaN         <1      500-999  ...  0.267333        1
# 19157              NaN          2          NaN  ...  0.285000        1
#
#        city_development_index_group  city_development_index_group_custom  \
# 0                     (0.878, 0.92]                           (0.5, inf]
# 1                    (0.691, 0.878]                           (0.5, inf]
# 2                    (0.447, 0.691]                           (0.5, inf]
# 3                    (0.691, 0.878]                           (0.5, inf]
# 4                    (0.691, 0.878]                           (0.5, inf]
# ...                             ...                                  ...
# 19153                (0.691, 0.878]                           (0.5, inf]
# 19154                 (0.878, 0.92]                           (0.5, inf]
# 19155                 (0.878, 0.92]                           (0.5, inf]
# 19156                (0.691, 0.878]                           (0.5, inf]
# 19157                (0.691, 0.878]                           (0.5, inf]
#
#        new_education_group  new_education_level  new_training_hours  \
# 0                     None             Graduate                 NaN
# 1                     None             Graduate                 NaN
# 2                     None             Graduate                 NaN
# 3                     None             Graduate                 NaN
# 4          Masters_and_phd      Masters_and_phd                 NaN
# ...                    ...                  ...                 ...
# 19153                 None             Graduate                 NaN
# 19154                 None             Graduate                 NaN
# 19155                 None             Graduate                 NaN
# 19156               School               School                 NaN
# 19157               School               School                 NaN
#
#       experience_int experience_group age
# 0                999    (18.0, 999.0]  30
# 1                 15     (11.0, 18.0]  30
# 2                  5       (4.0, 6.0]  30
# 3                  0    (-1.001, 4.0]  30
# 4                999    (18.0, 999.0]  30
# ...              ...              ...  ..
# 19153             14     (11.0, 18.0]  30
# 19154             14     (11.0, 18.0]  30
# 19155            999    (18.0, 999.0]  30
# 19156              0    (-1.001, 4.0]  30
# 19157              2    (-1.001, 4.0]  30
#
# [19158 rows x 25 columns]

# %%
len(df)
# Out:
# 19158

# %%
len(age)
# Out:
# 19158

# %%
len(age['enrollee_id'].drop_duplicates())
# Out:
# 19158

# %%
df.set_index('enrollee_id')
# Out:
#                  city  city_development_index   gender  \
# enrollee_id
# 8949         city_103                   0.920     Male
# 29725         city_40                   0.776     Male
# 11561         city_21                   0.624  no_info
# 33241        city_115                   0.789  no_info
# 666          city_162                   0.767     Male
# ...               ...                     ...      ...
# 7386         city_173                   0.878     Male
# 31398        city_103                   0.920     Male
# 24576        city_103                   0.920     Male
# 5756          city_65                   0.802     Male
# 23834         city_67                   0.855  no_info
#
#                  relevent_experience enrolled_university education_level  \
# enrollee_id
# 8949         Has relevent experience       no_enrollment        Graduate
# 29725         No relevent experience       no_enrollment        Graduate
# 11561         No relevent experience    Full time course        Graduate
# 33241         No relevent experience                 NaN        Graduate
# 666          Has relevent experience       no_enrollment         Masters
# ...                              ...                 ...             ...
# 7386          No relevent experience       no_enrollment        Graduate
# 31398        Has relevent experience       no_enrollment        Graduate
# 24576        Has relevent experience       no_enrollment        Graduate
# 5756         Has relevent experience       no_enrollment     High School
# 23834         No relevent experience       no_enrollment  Primary School
#
#             major_discipline experience company_size    company_type  ...  \
# enrollee_id                                                           ...
# 8949                    STEM        >20          NaN             NaN  ...
# 29725                   STEM         15        50-99         Pvt Ltd  ...
# 11561                   STEM          5          NaN             NaN  ...
# 33241        Business Degree         <1          NaN         Pvt Ltd  ...
# 666                     STEM        >20        50-99  Funded Startup  ...
# ...                      ...        ...          ...             ...  ...
# 7386              Humanities         14          NaN             NaN  ...
# 31398                   STEM         14          NaN             NaN  ...
# 24576                   STEM        >20        50-99         Pvt Ltd  ...
# 5756                     NaN         <1      500-999         Pvt Ltd  ...
# 23834                    NaN          2          NaN             NaN  ...
#
#              new col2  new_coll  city_development_index_group  \
# enrollee_id
# 8949         0.306667         1                 (0.878, 0.92]
# 29725        0.258667         1                (0.691, 0.878]
# 11561        0.208000         1                (0.447, 0.691]
# 33241        0.263000         1                (0.691, 0.878]
# 666          0.255667         1                (0.691, 0.878]
# ...               ...       ...                           ...
# 7386         0.292667         1                (0.691, 0.878]
# 31398        0.306667         1                 (0.878, 0.92]
# 24576        0.306667         1                 (0.878, 0.92]
# 5756         0.267333         1                (0.691, 0.878]
# 23834        0.285000         1                (0.691, 0.878]
#
#              city_development_index_group_custom  new_education_group  \
# enrollee_id
# 8949                                  (0.5, inf]                 None
# 29725                                 (0.5, inf]                 None
# 11561                                 (0.5, inf]                 None
# 33241                                 (0.5, inf]                 None
# 666                                   (0.5, inf]      Masters_and_phd
# ...                                          ...                  ...
# 7386                                  (0.5, inf]                 None
# 31398                                 (0.5, inf]                 None
# 24576                                 (0.5, inf]                 None
# 5756                                  (0.5, inf]               School
# 23834                                 (0.5, inf]               School
#
#              new_education_level new_training_hours experience_int  \
# enrollee_id
# 8949                    Graduate                NaN            999
# 29725                   Graduate                NaN             15
# 11561                   Graduate                NaN              5
# 33241                   Graduate                NaN              0
# 666              Masters_and_phd                NaN            999
# ...                          ...                ...            ...
# 7386                    Graduate                NaN             14
# 31398                   Graduate                NaN             14
# 24576                   Graduate                NaN            999
# 5756                      School                NaN              0
# 23834                     School                NaN              2
#
#             experience_group age
# enrollee_id
# 8949           (18.0, 999.0]  30
# 29725           (11.0, 18.0]  30
# 11561             (4.0, 6.0]  30
# 33241          (-1.001, 4.0]  30
# 666            (18.0, 999.0]  30
# ...                      ...  ..
# 7386            (11.0, 18.0]  30
# 31398           (11.0, 18.0]  30
# 24576          (18.0, 999.0]  30
# 5756           (-1.001, 4.0]  30
# 23834          (-1.001, 4.0]  30
#
# [19158 rows x 24 columns]

# %%
age
# Out:
#        enrollee_id  age
# 0             8949   30
# 1            29725   30
# 2            11561   30
# 3            33241   30
# 4              666   30
# ...            ...  ...
# 19153         7386   30
# 19154        31398   30
# 19155        24576   30
# 19156         5756   30
# 19157        23834   30
#
# [19158 rows x 2 columns]

# %%
age.groupby('enrollee_id')['age'].min()
# Out:
# enrollee_id
# 1        30
# 2        30
# 4        30
# 5        30
# 7        30
#          ..
# 33375    30
# 33376    30
# 33377    30
# 33379    30
# 33380    30
# Name: age, Length: 19158, dtype: int64

# %% [markdown]
# NUMPY library for massive

# %%
type(df['city_development_index'].values)
# Out:
# numpy.ndarray

# %%
import numpy as np

# %%
sum([1,2,3,4,5])
# Out:
# 15

# %%
np.mean([1,2,3,4,5])
# Out:
# 3.0

# %%
np.random.normal()
# Out:
# 0.2508164126596758

# %%
list(range(-10,0,10))
# Out:
# [-10]

# %%
np.linspace(-10,10)
# Out:
# array([-10.        ,  -9.59183673,  -9.18367347,  -8.7755102 ,
#         -8.36734694,  -7.95918367,  -7.55102041,  -7.14285714,
#         -6.73469388,  -6.32653061,  -5.91836735,  -5.51020408,
#         -5.10204082,  -4.69387755,  -4.28571429,  -3.87755102,
#         -3.46938776,  -3.06122449,  -2.65306122,  -2.24489796,
#         -1.83673469,  -1.42857143,  -1.02040816,  -0.6122449 ,
#         -0.20408163,   0.20408163,   0.6122449 ,   1.02040816,
#          1.42857143,   1.83673469,   2.24489796,   2.65306122,
#          3.06122449,   3.46938776,   3.87755102,   4.28571429,
#          4.69387755,   5.10204082,   5.51020408,   5.91836735,
#          6.32653061,   6.73469388,   7.14285714,   7.55102041,
#          7.95918367,   8.36734694,   8.7755102 ,   9.18367347,
#          9.59183673,  10.        ])

# %%
np.random.uniform(size=10) / 100
# Out:
# array([0.00672601, 0.00085373, 0.00614859, 0.00472146, 0.00136888,
#        0.00821453, 0.00779476, 0.00969664, 0.00326959, 0.00582723])

# %%
a=[1,2,3]
b=[2,3,2]

# %%
a+b
# Out:
# [1, 2, 3, 2, 3, 2]

# %%
a = np.array([1,2,3])
b = np.array([2,2,2])

# %%
a+b
# Out:
# array([3, 4, 5])

# %%
pd.DataFrame(a)
# Out:
#    0
# 0  1
# 1  2
# 2  3
